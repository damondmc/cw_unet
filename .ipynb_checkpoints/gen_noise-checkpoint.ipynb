# %%
#!/home/damoncht/.conda/envs/ml/bin/python
import numpy as np
from tqdm import tqdm 
from multiprocessing import Pool, cpu_count
import time
from genData import *
# Out:
# 25-06-01 14:02:11.093 pyfstat INFO    : Running PyFstat version 2.1.0
# /home/damoncht/.conda/envs/ml/lib/python3.9/site-packages/pyfstat/core.py:12: UserWarning: Wswiglal-redir-stdio:
#
# SWIGLAL standard output/error redirection is enabled in IPython.
# This may lead to performance penalties. To disable locally, use:
#
# with lal.no_swig_redirect_standard_output_error():
#     ...
#
# To disable globally, use:
#
# lal.swig_redirect_standard_output_error(False)
#
# Note however that this will likely lead to error messages from
# LAL functions being either misdirected or lost when called from
# Jupyter notebooks.
#
# To suppress this warning, use:
#
# import warnings
# warnings.filterwarnings("ignore", "Wswiglal-redir-stdio")
# import lal
#
#   import lal

# %%
t0 = time.time()
seed = 1
dataset = np.empty((10000, 512, 64, 4))
np.random.seed(seed)
for i in range(10000):
#     dataset[i] = simNoise(sqrtSn=1, Tsft=14400, size=(5000, 512,64), ndet=2, norm=True)
    dataset[i] = simNoise(sqrtSn=1, Tsft=14400, size=(512,64), ndet=2, norm=True)

#np.savez("./data/pure_noise/{}_purenoise_{}x{}_n{}_seed{}.npz".format('H1L1', 512, 64, 1000, seed), dataset=dataset)

print("Time used ={} s".format(time.time()-t0))
print("Dataset saved successfully.")
# Out:
# Time used =52.06144857406616 s
# Dataset saved successfully.
