# %%
import numpy as np
import torch
from tqdm import tqdm
from scipy.optimize import curve_fit
import sys
sys.path.append('../')

from plot import *
from utils import *
from genData import *
from model.unet import Attention_UNet


# Set random seeds for reproducibility
np.random.seed(1)
torch.manual_seed(1)

# Check for GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
if torch.cuda.is_available():
    print(f"GPU Name: {torch.cuda.get_device_name(0)}")
else:
    print("CUDA is not available. No GPU found.")
    
def compute_detection_statistic(images, method= 'mean'):
    images_np = np.abs(images)
                          
    return np.mean(np.square(images_np.transpose(0, 2, 3, 1)), axis=(1, 2, 3))


# Configuration
det = 'H1L1'
f0 = 1000
size = (512, 64)
Tsft = 14400
train_level = 19
batch_size = 8

# Model version
version = f'H1L1_a1b1_{f0}Hz_D{train_level}-{train_level}_T10_f512xTsft14400_ndata7000_noise7000_latent64_batch8_lr0.0001_512x64_MSELoss_dropout0'

# Load validation data (targets and masks)
filename = f'/scratch/kriles_root/kriles0/damoncht/unet_f/data/validation/{f0}Hz_H1L1_{size[0]}x{size[1]}_{Tsft}s_4c_traindata_n1000_seed4.npz'
val_data = np.load(filename, allow_pickle=True)
targets = val_data['clean_image']
masks = new_mask(normalize(targets))  # Assuming new_mask and normalize are defined in utils

# Load model
model = Attention_UNet(in_channels=4, out_channels=4, latent_channels=64, dropout_prob=0).to(device)
best_val_model = torch.load(f"../trained_model/{f0}Hz/best_pdet_model_mean_sq_{version}.pth", weights_only=False)
model.load_state_dict(best_val_model)
model.eval()

# Function to compute detection statistic
def compute_detection_statistic(images, method='mean_sq'):
    valid_methods = {'mean', 'mean_sq', 'kl_one', 'kl_random'}
    if method not in valid_methods:
        raise ValueError(f"Method must be one of {valid_methods}, got {method}")
    
    images_np = np.abs(images)
    if method == 'mean_sq':
        return np.mean(np.square(images_np.transpose(0, 2, 3, 1)), axis=(1, 2, 3))
# Out:
# 25-08-09 18:32:55.381 pyfstat INFO    : Running PyFstat version 2.1.0
# /home/damoncht/.conda/envs/ml/lib/python3.9/site-packages/pyfstat/core.py:12: UserWarning: Wswiglal-redir-stdio:
#
# SWIGLAL standard output/error redirection is enabled in IPython.
# This may lead to performance penalties. To disable locally, use:
#
# with lal.no_swig_redirect_standard_output_error():
#     ...
#
# To disable globally, use:
#
# lal.swig_redirect_standard_output_error(False)
#
# Note however that this will likely lead to error messages from
# LAL functions being either misdirected or lost when called from
# Jupyter notebooks.
#
# To suppress this warning, use:
#
# import warnings
# warnings.filterwarnings("ignore", "Wswiglal-redir-stdio")
# import lal
#
#   import lal
# GPU Name: Tesla V100-PCIE-16GB

# %%
# Initialize lists for depth and pdet
depth = []
pdet = []
max_train_levels = [5*i for i in range(2, 5)]  

# Compute pdet
noise_data = np.empty((1000,) + size + (4,))
for i in range(noise_data.shape[0]):
    noise_data[i] = simNoise(sqrtSn=1, Tsft=Tsft, size=size, ndet=2, norm=False)
noise_data = normalize(noise_data)
noise_loader = load_dataset(noise_data, batch_size=batch_size, shuffle=False)

noise_predictions = []
with torch.no_grad():
    for batch in tqdm(noise_loader, desc="Processing noise"):
        images = batch[0].to(device)
        outputs = model(images)
        noise_predictions.append(outputs.cpu().numpy())
noise_predictions = np.concatenate(noise_predictions, axis=0)
noise_stats = compute_detection_statistic(noise_predictions, method='mean_sq')

    
# Process each noise level one at a time
for Sn in max_train_levels:
    # Generate noise for current Sn
    noise = np.empty((targets.shape[0],) + size + (4,))
    for i in range(noise.shape[0]):
        noise[i] = simNoise(sqrtSn=Sn, Tsft=Tsft, size=size, ndet=2, norm=False)  # Assuming simNoise is defined
    data = normalize(noise + targets)
    data_loader = load_dataset(data, batch_size=batch_size, shuffle=False)

    # Compute predictions
    predictions = []
    with torch.no_grad():
        for images, in tqdm(data_loader, desc=f"Processing Sn={Sn}"):
            images = images.to(device)
            outputs = model(images)
            predictions.append(outputs.cpu().numpy())
    predictions = np.concatenate(predictions, axis=0)

    # Compute detection statistic
    stats = compute_detection_statistic(predictions, method='mean_sq')

    
    x_pfa = np.percentile(noise_stats, (1 - 0.71 / 100) * 100)
    mask = stats > x_pfa
    pdet_value = mask.sum() / mask.size

    # Store results
    depth.append(Sn)
    pdet.append(pdet_value)

# Convert to numpy arrays
depth = np.array(depth)
pdet = np.array(pdet)
# Out:
# Processing noise: 100%|██████████| 125/125 [00:05<00:00, 22.17it/s]
# Processing Sn=10: 100%|██████████| 125/125 [00:05<00:00, 22.34it/s]
# Processing Sn=15: 100%|██████████| 125/125 [00:05<00:00, 22.83it/s]
# Processing Sn=20: 100%|██████████| 125/125 [00:05<00:00, 23.53it/s]

# %%
# Create figure and axis
colors = plt.cm.tab10(np.linspace(0, 1, 10))  # Use tab10 colormap for distinct colors

fig, ax = plt.subplots(figsize=(10, 8))

# Plot Weave data as a line
#ax.plot(depth_mf[:-2], pdet_mf[:-2], color='k', label='Weave', lw=2)
sort_idx = np.argsort(depth)
depth_sorted = depth[sort_idx]
pdet_sorted = pdet[sort_idx]
p90 = 0.9
d90 = np.interp(p90, pdet_sorted[::-1], depth_sorted[::-1])  # Reverse to handle decreasing pdet

# Plot Attention UNet data with line and markers
ax.plot(depth, pdet, color=colors[0], linestyle='-', lw=2, marker='o', markersize=8, label='Attention UNet')

# Add horizontal and vertical lines at pdet = 0.9 and interpolated depth
ax.plot([0, d90], [p90, p90], color='red', linestyle='--', lw=1.5)
ax.plot([d90, d90], [-0.05, p90], color='red', linestyle='--', lw=1.5, 
        label=r'$\mathcal{D}^{90\%}=$' + f' {d90:.2f}')

# Axis labels and styling
ax.set_xlabel(r'$\mathcal{D}\; (\mathrm{Hz}^{-1/2})$')
ax.set_ylabel(r'$p_{\mathrm{det}}$')
ax.legend(fontsize=22, loc='upper right', markerscale=2, handlelength=2, handletextpad=0.5, bbox_to_anchor=(1, 0.8))
ax.grid(True, which='major', linestyle='dashed')
ax.set_xlim(0, 35)
ax.set_ylim(-0.05, 1.05)
ax.tick_params(axis='both', which='major', labelsize=22)
ax.minorticks_on()
ax.grid(True, which='minor', linestyle=':', alpha=0.3)

# Save figure
plt.tight_layout()
#plt.savefig(f'../result/plots/pdet_with_error_bars.pdf', dpi=300, bbox_inches='tight')

# %%
max_train_levels = [17, 17.5, 18]

depth_ex = []
pdet_ex = []
# Process each noise level one at a time
for Sn in max_train_levels:
    # Generate noise for current Sn
    noise = np.empty((targets.shape[0],) + size + (4,))
    for i in range(noise.shape[0]):
        noise[i] = simNoise(sqrtSn=Sn, Tsft=Tsft, size=size, ndet=2, norm=False)  # Assuming simNoise is defined
    data = normalize(noise + targets)
    data_loader = load_dataset(data, batch_size=batch_size, shuffle=False)

    # Compute predictions
    predictions = []
    with torch.no_grad():
        for images, in tqdm(data_loader, desc=f"Processing Sn={Sn}"):
            images = images.to(device)
            outputs = model(images)
            predictions.append(outputs.cpu().numpy())
    predictions = np.concatenate(predictions, axis=0)

    # Compute detection statistic
    stats = compute_detection_statistic(predictions, method='mean_sq')

    
    x_pfa = np.percentile(noise_stats, (1 - 0.71 / 100) * 100)
    mask = stats > x_pfa
    pdet_value = mask.sum() / mask.size

    # Store results
    depth_ex.append(Sn)
    pdet_ex.append(pdet_value)

# Convert to numpy arrays
depth_ex = np.array(depth_ex)
pdet_ex = np.array(pdet_ex)
# Out:
# Processing Sn=17: 100%|██████████| 125/125 [00:05<00:00, 23.33it/s]
# Processing Sn=17.5: 100%|██████████| 125/125 [00:05<00:00, 21.34it/s]
# Processing Sn=18: 100%|██████████| 125/125 [00:05<00:00, 22.90it/s]

# %%
# Insert depth_ex and pdet_ex into depth and pdet to maintain ascending order
# Combine all points
combined = np.vstack((np.column_stack((depth, pdet)), np.column_stack((depth_ex, pdet_ex))))
# Sort by depth (first column)
sorted_indices = np.argsort(combined[:, 0])
depth_combined = combined[sorted_indices, 0]
pdet_combined = combined[sorted_indices, 1]

# Use only the first len(depth)-4 points from combined data (to match depth[:-4])
n_points = len(depth_combined)
depth_plot = depth_combined[:n_points]
pdet_plot = pdet_combined[:n_points]

# Interpolate depth at pdet = 0.9
# Sort by depth for interpolation (already sorted, but confirm)
sort_idx = np.argsort(depth_plot)
depth_sorted = depth_plot[sort_idx]
pdet_sorted = pdet_plot[sort_idx]

dpdet = binomialError(pdet_sorted, 1000)

# Compute interpolation and error
d90, d90_err = interpolation_error(0.9, depth_sorted, pdet_sorted, dpdet)

# Create figure and axis
fig, ax = plt.subplots(figsize=(9, 8))
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

# Plot combined Attention UNet data with line and markers
ax.plot(depth_plot, pdet_plot, color=colors[0], linestyle='-', lw=2, marker='o', markersize=8, label='Attention UNet')

# Add horizontal and vertical lines at pdet = 0.9 and interpolated depth
ax.plot([0, d90], [p90, p90], color='red', linestyle='--', lw=1.5)
ax.plot([d90, d90], [-0.05, p90], color='red', linestyle='--', lw=1.5, 
        label=r'$\mathcal{D}^{90\%}=$' + f' {d90:.2f}'r'$\pm$'+ f'{d90_err:.2f}')

# Axis labels and styling
ax.set_xlabel(r'$\mathcal{D}\; (\mathrm{Hz}^{-1/2})$', fontsize=25)
ax.set_ylabel(r'$p_{\mathrm{det}}$', fontsize=25)
ax.legend(fontsize=25, loc=1, markerscale=2, handlelength=2, handletextpad=0.5, edgecolor='k')
ax.grid(True, which='major', linestyle='dashed')
ax.set_xlim(0, 55)
ax.set_ylim(0, 1.05)
ax.tick_params(axis='both', which='major', labelsize=25)
ax.minorticks_on()
ax.grid(True, which='minor', linestyle=':', alpha=0.3)

# Save figure
plt.tight_layout()
#plt.savefig('../result/plots/pdet_20Hz.pdf', dpi=300, bbox_inches='tight')

# %%
max_train_levels = [34.5]

depth_ex = []
pdet_ex = []
# Process each noise level one at a time
for Sn in max_train_levels:
    # Generate noise for current Sn
    noise = np.empty((targets.shape[0],) + size + (4,))
    for i in range(noise.shape[0]):
        noise[i] = simNoise(sqrtSn=Sn, Tsft=Tsft, size=size, ndet=2, norm=False)  # Assuming simNoise is defined
    data = normalize(noise + targets)
    data_loader = load_dataset(data, batch_size=batch_size, shuffle=False)

    # Compute predictions
    predictions = []
    with torch.no_grad():
        for images, in tqdm(data_loader, desc=f"Processing Sn={Sn}"):
            images = images.to(device)
            outputs = model(images)
            predictions.append(outputs.cpu().numpy())
    predictions = np.concatenate(predictions, axis=0)

    # Compute detection statistic
    stats = compute_detection_statistic(predictions, method='mean_sq')

    
    x_pfa = np.percentile(noise_stats, (1 - 0.71 / 100) * 100)
    mask = stats > x_pfa
    pdet_value = mask.sum() / mask.size

    # Store results
    depth_ex.append(Sn)
    pdet_ex.append(pdet_value)

# Convert to numpy arrays
depth_ex = np.array(depth_ex)
pdet_ex = np.array(pdet_ex)
# Out:
# Processing Sn=34.5: 100%|██████████| 125/125 [00:05<00:00, 23.63it/s]

# %%
depth_ex, pdet_ex
# Out:
# (array([34.5]), array([0.328]))

# %%
binomialError(pdet_ex, 1000)*100
# Out:
# array([1.48464137])

# %%
# Configuration
det = 'H1L1'
f0 = 1000
size = (512, 64)
Tsft = 14400
train_level = 19
batch_size = 8

# Model version
version = f'H1L1_a1.0b1.0_{f0}Hz_D{train_level}-{train_level}_T10_Tsft14400_ndata10000_noise10000_latent128_batch8_lr0.0001_512x64_MSELoss_dropout0'

# Load validation data (targets and masks)
filename = f'/scratch/kriles_root/kriles0/damoncht/unet_f/data/validation/{f0}Hz_H1L1_{size[0]}x{size[1]}_{Tsft}s_4c_traindata_n1000_seed4.npz'
val_data = np.load(filename, allow_pickle=True)
targets = val_data['clean_image']
masks = new_mask(normalize(targets))  # Assuming new_mask and normalize are defined in utils

# Load model
model = Attention_UNet(in_channels=4, out_channels=4, latent_channels=128, dropout_prob=0).to(device)
best_val_model = torch.load(f"../trained_model/{f0}Hz/best_pdet_model_mean_sq_{version}.pth", weights_only=False)
model.load_state_dict(best_val_model)
model.eval()
# Out:
# Attention_UNet(
#   (Maxpool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (Upsample): Upsample(scale_factor=2.0, mode='nearest')
#   (encoder): ModuleList(
#     (0): conv_block(
#       (conv): Sequential(
#         (0): Conv2d(4, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.01, inplace=True)
#         (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): LeakyReLU(negative_slope=0.01, inplace=True)
#       )
#     )
#     (1): conv_block(
#       (conv): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.01, inplace=True)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): LeakyReLU(negative_slope=0.01, inplace=True)
#       )
#     )
#     (2): conv_block(
#       (conv): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.01, inplace=True)
#         (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): LeakyReLU(negative_slope=0.01, inplace=True)
#       )
#     )
#     (3): conv_block(
#       (conv): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.01, inplace=True)
#         (3): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): LeakyReLU(negative_slope=0.01, inplace=True)
#       )
#     )
#   )
#   (bottleneck): Sequential(
#     (0): conv_block(
#       (conv): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.01, inplace=True)
#         (3): Conv2d(2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): LeakyReLU(negative_slope=0.01, inplace=True)
#       )
#     )
#     (1): Identity()
#   )
#   (decoder): ModuleList(
#     (0): conv_block(
#       (conv): Sequential(
#         (0): Conv2d(2048, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.01, inplace=True)
#         (3): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): LeakyReLU(negative_slope=0.01, inplace=True)
#       )
#     )
#     (1): conv_block(
#       (conv): Sequential(
#         (0): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.01, inplace=True)
#         (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): LeakyReLU(negative_slope=0.01, inplace=True)
#       )
#     )
#     (2): conv_block(
#       (conv): Sequential(
#         (0): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.01, inplace=True)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): LeakyReLU(negative_slope=0.01, inplace=True)
#       )
#     )
#     (3): conv_block(
#       (conv): Sequential(
#         (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.01, inplace=True)
#         (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): LeakyReLU(negative_slope=0.01, inplace=True)
#       )
#     )
#   )
#   (upsample_layer): ModuleList(
#     (0): up_conv(
#       (up): Sequential(
#         (0): Upsample(scale_factor=2.0, mode='nearest')
#         (1): Conv2d(2048, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): LeakyReLU(negative_slope=0.01, inplace=True)
#       )
#     )
#     (1): up_conv(
#       (up): Sequential(
#         (0): Upsample(scale_factor=2.0, mode='nearest')
#         (1): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): LeakyReLU(negative_slope=0.01, inplace=True)
#       )
#     )
#     (2): up_conv(
#       (up): Sequential(
#         (0): Upsample(scale_factor=2.0, mode='nearest')
#         (1): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): LeakyReLU(negative_slope=0.01, inplace=True)
#       )
#     )
#     (3): up_conv(
#       (up): Sequential(
#         (0): Upsample(scale_factor=2.0, mode='nearest')
#         (1): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): LeakyReLU(negative_slope=0.01, inplace=True)
#       )
#     )
#   )
#   (attention_layer): ModuleList(
#     (0): Attention_block(
#       (W_g): Sequential(
#         (0): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (W_x): Sequential(
#         (0): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (psi): Sequential(
#         (0): Conv2d(512, 1, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): Sigmoid()
#       )
#       (relu): LeakyReLU(negative_slope=0.01, inplace=True)
#     )
#     (1): Attention_block(
#       (W_g): Sequential(
#         (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (W_x): Sequential(
#         (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (psi): Sequential(
#         (0): Conv2d(256, 1, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): Sigmoid()
#       )
#       (relu): LeakyReLU(negative_slope=0.01, inplace=True)
#     )
#     (2): Attention_block(
#       (W_g): Sequential(
#         (0): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (W_x): Sequential(
#         (0): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (psi): Sequential(
#         (0): Conv2d(128, 1, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): Sigmoid()
#       )
#       (relu): LeakyReLU(negative_slope=0.01, inplace=True)
#     )
#     (3): Attention_block(
#       (W_g): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (W_x): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (psi): Sequential(
#         (0): Conv2d(64, 1, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): Sigmoid()
#       )
#       (relu): LeakyReLU(negative_slope=0.01, inplace=True)
#     )
#   )
#   (output_layer): Sequential(
#     (0): Conv2d(128, 4, kernel_size=(1, 1), stride=(1, 1))
#     (1): Tanh()
#   )
# )

# %%
# Initialize lists for depth and pdet
depth = []
pdet = []
max_train_levels = [5*i for i in range(2, 5)]  
def load_dataset(images, batch_size=8, shuffle=True):

    # Convert to torch tensors
    images_tensor = torch.tensor(images, dtype=torch.float32).permute(0, 3, 1, 2)
    dataset = TensorDataset(images_tensor)
    data_loader = DataLoader(dataset, batch_size=batch_size, shuffle=shuffle)

    return data_loader


# Compute pdet
noise_data = np.empty((1000,) + size + (4,))
for i in range(noise_data.shape[0]):
    noise_data[i] = simNoise(sqrtSn=1, Tsft=Tsft, size=size, ndet=2, norm=False)
noise_data = normalize(noise_data)
noise_loader = load_dataset(noise_data, batch_size=batch_size, shuffle=False)

noise_predictions = []
with torch.no_grad():
    for batch in tqdm(noise_loader, desc="Processing noise"):
        images = batch[0].to(device)
        outputs = model(images)
        noise_predictions.append(outputs.cpu().numpy())
noise_predictions = np.concatenate(noise_predictions, axis=0)
noise_stats = compute_detection_statistic(noise_predictions, method='mean_sq')

    
# Process each noise level one at a time
for Sn in max_train_levels:
    # Generate noise for current Sn
    noise = np.empty((targets.shape[0],) + size + (4,))
    for i in range(noise.shape[0]):
        noise[i] = simNoise(sqrtSn=Sn, Tsft=Tsft, size=size, ndet=2, norm=False)  # Assuming simNoise is defined
    data = normalize(noise + targets)
    data_loader = load_dataset(data, batch_size=batch_size, shuffle=False)

    # Compute predictions
    predictions = []
    with torch.no_grad():
        for images, in tqdm(data_loader, desc=f"Processing Sn={Sn}"):
            images = images.to(device)
            outputs = model(images)
            predictions.append(outputs.cpu().numpy())
    predictions = np.concatenate(predictions, axis=0)

    # Compute detection statistic
    stats = compute_detection_statistic(predictions, method='mean_sq')

    
    x_pfa = np.percentile(noise_stats, (1 - 0.71 / 100) * 100)
    mask = stats > x_pfa
    pdet_value = mask.sum() / mask.size

    # Store results
    depth.append(Sn)
    pdet.append(pdet_value)

# Convert to numpy arrays
depth = np.array(depth)
pdet = np.array(pdet)


max_train_levels = [17, 17.5, 18]

depth_ex = []
pdet_ex = []
# Process each noise level one at a time
for Sn in max_train_levels:
    # Generate noise for current Sn
    noise = np.empty((targets.shape[0],) + size + (4,))
    for i in range(noise.shape[0]):
        noise[i] = simNoise(sqrtSn=Sn, Tsft=Tsft, size=size, ndet=2, norm=False)  # Assuming simNoise is defined
    data = normalize(noise + targets)
    data_loader = load_dataset(data, batch_size=batch_size, shuffle=False)

    # Compute predictions
    predictions = []
    with torch.no_grad():
        for images, in tqdm(data_loader, desc=f"Processing Sn={Sn}"):
            images = images.to(device)
            outputs = model(images)
            predictions.append(outputs.cpu().numpy())
    predictions = np.concatenate(predictions, axis=0)

    # Compute detection statistic
    stats = compute_detection_statistic(predictions, method='mean_sq')

    
    x_pfa = np.percentile(noise_stats, (1 - 0.71 / 100) * 100)
    mask = stats > x_pfa
    pdet_value = mask.sum() / mask.size

    # Store results
    depth_ex.append(Sn)
    pdet_ex.append(pdet_value)

# Convert to numpy arrays
depth_ex = np.array(depth_ex)
pdet_ex = np.array(pdet_ex)
# Out:
# Processing noise: 100%|██████████| 125/125 [00:19<00:00,  6.45it/s]
# Processing Sn=10: 100%|██████████| 125/125 [00:19<00:00,  6.49it/s]
# Processing Sn=15: 100%|██████████| 125/125 [00:19<00:00,  6.35it/s]
# Processing Sn=20: 100%|██████████| 125/125 [00:20<00:00,  6.09it/s]
# Processing Sn=17: 100%|██████████| 125/125 [00:20<00:00,  6.24it/s]
# Processing Sn=17.5: 100%|██████████| 125/125 [00:19<00:00,  6.36it/s]
# Processing Sn=18: 100%|██████████| 125/125 [00:20<00:00,  6.15it/s]

# %%
# Insert depth_ex and pdet_ex into depth and pdet to maintain ascending order
# Combine all points
combined = np.vstack((np.column_stack((depth, pdet)), np.column_stack((depth_ex, pdet_ex))))
# Sort by depth (first column)
sorted_indices = np.argsort(combined[:, 0])
depth_combined = combined[sorted_indices, 0]
pdet_combined = combined[sorted_indices, 1]

# Use only the first len(depth)-4 points from combined data (to match depth[:-4])
n_points = len(depth_combined)
depth_plot = depth_combined[:n_points]
pdet_plot = pdet_combined[:n_points]

# Interpolate depth at pdet = 0.9
# Sort by depth for interpolation (already sorted, but confirm)
sort_idx = np.argsort(depth_plot)
depth_sorted = depth_plot[sort_idx]
pdet_sorted = pdet_plot[sort_idx]

dpdet = binomialError(pdet_sorted, 1000)

# Compute interpolation and error
d90, d90_err = interpolation_error(0.9, depth_sorted, pdet_sorted, dpdet)

# Create figure and axis
fig, ax = plt.subplots(figsize=(9, 8))
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

# Plot combined Attention UNet data with line and markers
ax.plot(depth_plot, pdet_plot, color=colors[0], linestyle='-', lw=2, marker='o', markersize=8, label='Attention UNet')

# Add horizontal and vertical lines at pdet = 0.9 and interpolated depth
ax.plot([0, d90], [p90, p90], color='red', linestyle='--', lw=1.5)
ax.plot([d90, d90], [-0.05, p90], color='red', linestyle='--', lw=1.5, 
        label=r'$\mathcal{D}^{90\%}=$' + f' {d90:.2f}'r'$\pm$'+ f'{d90_err:.2f}')

# Axis labels and styling
ax.set_xlabel(r'$\mathcal{D}\; (\mathrm{Hz}^{-1/2})$', fontsize=25)
ax.set_ylabel(r'$p_{\mathrm{det}}$', fontsize=25)
ax.legend(fontsize=25, loc=1, markerscale=2, handlelength=2, handletextpad=0.5, edgecolor='k')
ax.grid(True, which='major', linestyle='dashed')
ax.set_xlim(0, 25)
ax.set_ylim(0, 1.05)
ax.tick_params(axis='both', which='major', labelsize=25)
ax.minorticks_on()
ax.grid(True, which='minor', linestyle=':', alpha=0.3)

# Save figure
plt.tight_layout()
#plt.savefig('../result/plots/pdet_20Hz.pdf', dpi=300, bbox_inches='tight')

# %%
max_train_levels = [34.5]

depth_ex = []
pdet_ex = []
# Process each noise level one at a time
for Sn in max_train_levels:
    # Generate noise for current Sn
    noise = np.empty((targets.shape[0],) + size + (4,))
    for i in range(noise.shape[0]):
        noise[i] = simNoise(sqrtSn=Sn, Tsft=Tsft, size=size, ndet=2, norm=False)  # Assuming simNoise is defined
    data = normalize(noise + targets)
    data_loader = load_dataset(data, batch_size=batch_size, shuffle=False)

    # Compute predictions
    predictions = []
    with torch.no_grad():
        for images, in tqdm(data_loader, desc=f"Processing Sn={Sn}"):
            images = images.to(device)
            outputs = model(images)
            predictions.append(outputs.cpu().numpy())
    predictions = np.concatenate(predictions, axis=0)

    # Compute detection statistic
    stats = compute_detection_statistic(predictions, method='mean_sq')

    
    x_pfa = np.percentile(noise_stats, (1 - 0.71 / 100) * 100)
    mask = stats > x_pfa
    pdet_value = mask.sum() / mask.size

    # Store results
    depth_ex.append(Sn)
    pdet_ex.append(pdet_value)

# Convert to numpy arrays
depth_ex = np.array(depth_ex)
pdet_ex = np.array(pdet_ex)
# Out:
# Processing Sn=34.5: 100%|██████████| 125/125 [00:19<00:00,  6.38it/s]

# %%
depth_ex, pdet_ex
# Out:
# (array([34.5]), array([0.365]))

# %%
binomialError(pdet_ex, 1000)*100
# Out:
# array([1.52241584])
